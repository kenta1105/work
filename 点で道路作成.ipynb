# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
x1 = []
y1 = []
load = []
for i in range(0,400):
    x = 0
    y = i
    x1.append(x)
    y1.append(y)

# %%
plt.scatter(x1,y1)
